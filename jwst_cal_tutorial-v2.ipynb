# %% [markdown]
# <a id="title_ID"></a>
# # JWST Pipeline Validation Notebook:
# # Calwebb_coron3 for MIRI coronagraphic imaging
#
# ### Table of Contents
#
# <br> [Introduction](#intro)
# <br> [JWST CalWG Algorithm](#algorithm)
# <br> [Defining Terms](#terms)
# <br> [Test Description](#test_descr)
# <br> [Data Description](#data_descr)
# <br> [Imports](#imports)
# <br> [Load Input Data](#data_load)
# <br> [Run the Pipeline](#run_pipeline)
# <br> [Examine Outputs](#output)
# <br> [About This Notebook](#about)

# %% [markdown]
# <a id="intro"></a>
# # Introduction
#
# This is a tutorial notebook for processing MIRISim coronagraphic data through the JWST calibration pipeline.
#
# - Module descriptions:
#   - Stage 1 (Detector artifacts) https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_detector1.html
#   - Stage 2 (Image calibration) https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_image2.html
#   - Stage 3 (Coronagraph) https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_coron3.html#calwebb-coron3
#
#
# - Pipeline code: https://github.com/spacetelescope/jwst/blob/master/jwst/coron/
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="stage_3_algorithm"></a>
# # JWST Stage3 Algorithm
#
#
# The algorithms for `CALWEBB_CORON3` are as follows:
#
# - **Assemble Reference PSFs**: <br>
# All the available reference PSFs are assembled into the appropriate association.
#
#
# - **Outlier detection**: <br>
# An iterative sigma clipping algorithm is used in pixel coordinates on the image stack. The presence of an outlier results in a pixel flag being set.
#
#
# - **Align reference PSFs**: <br>
# The reference PSFs are aligned with the target observation using the Fourier LSQ algorithm to measure the shifts and the Fourier Shift algorithm to apply the shifts to each reference PSF integration.
#
#
# - **Reference PSF subtraction**: <br>
# The reference PSF that is subtracted from each target integration is created using the list of reference PSFs and the KLIP algorithm.
#
#
# - **Image Combination**: <br>
# The target images (including those at different rotations) are combined into a single combined image using the AstroDrizzle code (with the output pixel size set to the input pixel size).
#
#
# - **Updated Exposure Level Products**: <br>
# The exposure level products are re-created to provide the highest quality products that include the results of the ensemble processing (updated WCS, matching backgrounds, and 2nd pass outlier detection).
#
# <BR>
#
# The current status of these algorithms are summarized in the link below:
#
# > https://outerspace.stsci.edu/display/JWSTCC/CALWEBB_CORON3
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="terms"></a>
# # Defining Terms
#
# - **JWST**: James Webb Space Telescope ([see documentation](https://jwst-docs.stsci.edu/))
# - **MIRI**: Mid-Infrared Instrument ([see documentation](https://jwst-docs.stsci.edu/mid-infrared-instrument))
# - **4QPM**: 4 Quadrant Phase Mask ([see documentation](https://jwst-docs.stsci.edu/mid-infrared-instrument/miri-instrumentation/miri-coronagraphs#MIRICoronagraphs-4qpm))
# - **Lyot**: coronagraph design incorporating a classical Lyot spot ([see documentation](https://jwst-docs.stsci.edu/mid-infrared-instrument/miri-instrumentation/miri-coronagraphs#MIRICoronagraphs-lyotcoron))
#
#  [Top of Page](#title_ID)

# %% [markdown]
# <a id="data_descr"></a>
# # Data Description
#
# ### Input Data:
#
# For Stage 3 processing, the data set must contain both science exposures and PSF references. These can be demarcated however you like, and may even have the same file name as long as they have different paths. For MIRISim data this is often the case; however, for the purposes of this tutorial, the data at have all been collected in the same folder and given unique names. The simulated exposures are available here:
# > https://stsci.box.com/s/tk52601kge1rhhcim9kf1al0x2bee4s3
#
# The data have the following naming format:
# - Science exposures:
#     - `Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1.fits`
#     - `Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll2.fits`
#
# - Reference PSF exposures:
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-1.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-2.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-3.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-4.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-5.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-6.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-7.fits`
#     - `piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-8.fits`
#
#
#
#
# ### Reference Files:
#
# The `align_refs` step requires a PSFMASK reference file containing a 2D mask that’s used as a weight function when computing shifts between images.
#
# > File description: https://jwst-pipeline.readthedocs.io/en/latest/jwst/align_refs/description.html#psfmask-reffile
#
# Currently the PSFMASK reference files ingested into CRDS are incorrect (wrong shape and incorrectly centered around coronagraphic obstructions), therefore an updated file is used for these tests:
#
# > https://github.com/STScI-MIRI/Gen_PSFMASK_ref_files/tree/main/psf_masks_new
#
# Choose the file associated with the coronagraphic filter that matches your data.
#
#
# ### Association File:
#
# Currently the individual stage 3 coronagraphic processing steps can only be run in a convenient way by running the `calwebb_coron3` pipeline on an association (ASN) file that lists the various science target and reference PSF exposures to be processed.
#
# > Level 3 Associations documentation: https://jwst-pipeline.readthedocs.io/en/latest/jwst/associations/level3_asn_rules.html
#
# Normally an association file would be generated automatically and provided along with the data, but in this case we will generate an association file for this step.
#
#
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="imports_ID"></a>
# # Imports
#
# * `astropy.io` for opening fits files
# * `jwst` is the JWST Calibration Pipeline
# * `jwst.Coron3Pipeline` is the pipeline being tested
# * `matplotlib` and `matplotlib.pyplot` to generate plots
# * `numpy` for array calculations and manipulation
# * `asn_from_list` for generating Stage 3 coronagraph association files
#
# [Top of Page](#title_ID)

# %%
from astropy.io import fits
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.close_figures=False # To prevent automatic figure display when execution of the cell ends
import numpy as np

import jwst
from jwst.pipeline import Detector1Pipeline, Image2Pipeline, Coron3Pipeline
from jwst.associations.asn_from_list import asn_from_list

# %%
jwst.__version__
# should be '1.3.3'
# Out:
# '1.3.3'

# %% [markdown]
# ### Detector1Pipeline

# %% [markdown]
# <a id="data_load"></a>
# # Load Input Data

# %% [markdown]
# I like to use a dictionary to keep track of my file paths because the dictionary key can be used to store file metadata, like if it's a science target or a reference image. In the cell below, I collect my files together and assign them the appropriate keys.

# %%
from pathlib import Path
data_files = {
    # science targets
    'roll1': Path("data/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1.fits"),
    'roll2': Path("data/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll2.fits")
}
# reference targets
psf_path = Path("data")
data_files.update(
    {'psf'+p.stem[-1]: p for p in sorted(psf_path.glob("piHer*fits"))}
                 )

# %%
data_files
# Out:
# {'roll1': PosixPath('data/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1.fits'),
#  'roll2': PosixPath('data/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll2.fits'),
#  'psf0': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0.fits'),
#  'psf1': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-1.fits'),
#  'psf2': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-2.fits'),
#  'psf3': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-3.fits'),
#  'psf4': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-4.fits'),
#  'psf5': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-5.fits'),
#  'psf6': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-6.fits'),
#  'psf7': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-7.fits'),
#  'psf8': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-8.fits')}

# %%
# Make sure the CORONMSK header is set; MIRISim misses this sometimes
for k, data_file in data_files.items():
    try:
        fits.getval(data_file, 'CORONMSK', ext=0)
    except KeyError:
        print("CORONMSK not found, writing to header")
        fits.setval(data_file, keyword="CORONMSK", value="4QPM_1550", ext=0, comment="Coronagraphic mask", savecomment=False)

# %%
data_files
# Out:
# {'roll1': PosixPath('data/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1.fits'),
#  'roll2': PosixPath('data/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll2.fits'),
#  'psf0': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0.fits'),
#  'psf1': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-1.fits'),
#  'psf2': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-2.fits'),
#  'psf3': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-3.fits'),
#  'psf4': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-4.fits'),
#  'psf5': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-5.fits'),
#  'psf6': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-6.fits'),
#  'psf7': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-7.fits'),
#  'psf8': PosixPath('data/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-8.fits')}

# %% [markdown]
# [Top of Page](#title_ID)
# <a id="run_pipeline"></a>
#
#
# ------------
# # Run the Pipeline
#
# In this tutorial, we have the choice to use configuration files to explicitly set all parameters, as an example for the user. In actual practice, all parameters will at least take the default value unless otherwise specified. The upshot of this is that the user should *only* provide parameters that they wish to change from the default. In general, the pipeline default values are chosen to provide the optimal output for properly calibrated science products. By only providing values for parameters that they explicitly wish to change, users will prevent themselves from unintentionally overriding the default pipeline parameters in the case of a pipeline update where the default values are changed.

# %% [markdown]
# ## Universal parameters
# You can pass these parameters to any pipeline stage or step.
# - Save results
#     - `save_results=[bool]`
#     - if True, save the results to a file specified by `output_dir` and `output_file` (uses defaults if none specified)
# - Output directory
#     - `output_dir=[path]`
#     - directory where output files will be written
# - Output file prefix
#     - `output_file=[basename]`
#     - file prefix for output files
# - Reference file override
#     - `override_<ref_type>=[path to reference file to use instead`
#     - use the provided reference file instead of the one automatically selected by CRDS
#     - `<ref_type>` is the name of the reference file type in lowercase, e.g. `dark`, `mask`, `gain`, `linearity`, `psfmask`
# - Skip
#     - `skip=[bool]`
#     - skip a step if you want; the output of the previous step will be provided to the input of the following step
# - Logging configuration file
#     - `logcfg=[log config file name]`
#     - specify where to place the log and the level of detail to record
#     - see https://jwst-pipeline.readthedocs.io/en/latest/jwst/introduction.html#logging-configuration for formatting
#
# Additionall, the `Detector1Pipeline`, `Image2Pipeline`, and `Coron3Pipeline` classes can accept the `steps` argument to pass step-specific arguments to a specified step. This takes a dictionary with the following structure:
#
#     step_args = {
#                  'step1_name': {arg: val},
#                  'step2_name': {arg1: val1, arg2: val2}
#                 }
#
#
# The following parameters are technically available but should *not* be included by users in a parameter reference, as per https://jwst-pipeline.readthedocs.io/en/latest/jwst/stpipe/config_asdf.html?highlight=output_ext#jwst-parameters-and-parameter-references:
# - `input_dir`
# - `output_ext`
# - `output_use_index`
#     - cannot find documentation
# - `output_use_model`
#     - True to always base output file names on the DataModel.meta.filename of the DataModel being saved
# - `pre_hooks`
#     - command-line hooks to run just before a step
#     - uses same input as parent step
# - `post_hooks`
#     - command-line hooks to run just after a step
#     - uses same input as parent step
# - `save_results`
# - `search_output_file`
#     - True to retrieve the output_file from a parent Step or Pipeline

# %% [markdown]
# ## Parameter files
#
# You can pass parameters through the class interface (`.run()` or `.call()`), or you can place them in a parameter file. There are three parameter files for each stage of the pipeline in the `parameter_files` subfolder - one with all the parameters, one with only the parameters that are unique to each stage and/or step, and one that only includes modified arguments for use during these examples.

# %%
# Let's generate and save the stage parameter files with their default values. Then, you can edit them as you please
if False: # set to True to regenerate config files
    Detector1Pipeline().export_config("parameter_files/stage1_parameters.asdf")
    Image2Pipeline().export_config("parameter_files/stage2_parameters.asdf")
    Coron3Pipeline().export_config("parameter_files/stage3_parameters.asdf")

# %%
# You can also get the parameters as a dictionary object
if False: # set to True to create these dictionaries
    stage_1_pars = Detector1Pipeline().get_pars()
    stage_2_pars = Image2Pipeline().get_pars()
    stage_3_pars = Coron3Pipeline().get_pars()

# %%
from jwst import datamodels

# %% [markdown]
# #  Stage 1: Detector effects correction

# %% [markdown]
# Class name: `Detector1Pipeline`
#
# > https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_detector1.html
#
# Stage 1 consists of detector-level corrections that are performed on a group-by-group basis, followed by ramp fitting. The output of stage 1 processing is a countrate image per exposure, or per integration for some modes.
#
#
# It uses the following parameters, in addition to the universal parameters:
# - `save_calibrated_ramp`
#     - takes bool `[False]`
#     - if True, save intermediate data to a file as it exists after the `jump` step and before the `ramp_fit` step

# %% [markdown]
# The steps (in order of execution, I think) are:
# - `group_scale`
#     - group scale correction;
#     - rescales pixel values in raw JWST science data products to correct for instances where on-board frame averaging didn't result in the proper downlinked values
#     - no step-specific arguments
#     - does not use any reference files
# - `dq_init`
#     - data quality initialization
#     - populates the DQ mask for the input dataset
#     - no step-specific arguments
#     - reference file: MASK
# - `saturation`
#     - flags pixels at or below the A/D floor (< 0 DN) or above the saturation threshold
#     - no step-specific arguments
#     - reference file: SATURATION
# - `ipc`
#     - interpixel capacitance
#     - corrects for ipc by convolving with an IPC reference image
#     - no step-specific arguments
#     - reference file: IPC
# - `firstframe`
#     - only for MIRI; flags the first group in every integration as bad (sets DO_NOT_USE DQ bit)
#     - no step-specific arguments
#     - no reference file used
# - `lastframe`
#     - only for MIRI; flags the final group in each integration as bad (sets DO_NOT_USE DQ bit)
#     - no step-specific arguments
#     - no reference file used
# - `linearity`
#     - linearity correction
#     - correction is applied pixel-by-pixel, group-by-group, integration-by-integration within a science exposure
#     - no step-specific arguments
#     - reference file: LINEARITY
# - `rscd`
#     - Reset Switch Charge Decay (RSCD) Correction
#     - only for MIRI, and only applied after the first integration
#     - flags N groups as DO_NOT_USE if the charge in the reset switches has not sufficienty decayed?
#     - no step-specific arguments
#     - reference file: RSCD
# - `dark_current`
#     - dark current subtraction
#     - subtracts dark current data stored in a dark reference file
#     - one step-specific argument:
#         - `dark_output filename`; saves the frame-averaged dark data to this file
#     - reference file: DARK
# - `refpix`
#     - reference pixel correction
#     - uses reference pixels to correct for drifts in the readout amplifiers
#     - step arguments:
#         - `odd_even_columns bool [True]`; odd and even columns are treated separately
#         - `use_side_ref_pixels bool [True]`; only for NIR data
#         - `side_smoothing_length int [11]`: height of the window used for the running median calculation
#         - `side_gain float [1.0]` how much to multiply the side reference signal before subtraction
#         - `odd_even_rows bool [True]` calculate reference signal separately for odd and even rows; only for MIR
#     - reference file: DARK
# - `jump`
#     - detects jumps in an exposure (after saturation step has been applied)
#     - looks for outliers in up-the-ramp read
#     - skips automatically if ngroups/integration < 3
#     - step-specific arguments:
#         - `rejection_threshold float [4.0]` sigma rejection threshold
#         - `maximum_cores string [none]` fraction of available cores to use
#         - `flag_4_neighbors bool [True]` if jump is detected, flag 4 neighbors as jumps too
#         - `max_jump_to_flag_neighbors float [200]` sigma threshold to limit automatic neighbor flagging (so they will be flagged as primary jumps, and *their* neighbors can be flagged
#         - `min_jump_to_flag_naighbors float [10]` limits flagging of neighbors of marginal jump detections.
#     - two reference files:
#         - GAIN
#         - READNOISE
# - `ramp_fitting`
#     - fits a line to the group data in the input file to determine the count rate
#     - step-specific arguments:
#         - `save_opt bool [False]` write optional output product
#         - `opt_name str` overrides the default name for the output product
#         - `int_name str` overrides the default name for the per-integration product
#         - `maximum_cores str [none]` fraction of cores to use for multiprocessing
#     - reference files:
#         - GAIN
#         - READNOISE
# - `gain_scale`
#     - rescales pixel values in countrate science data products to correct for the effect of using a non-standard detector gain setting
#     - makes them appear as if standard gain setting had been used
#     - currently only for NIRSPEC
#     - no step-specific arguments
#     - reference file: GAIN

# %% [markdown]
# OK, let's assemble a dictionary of arguments for Stage 1. We want to change the output directory, and we want to save the frame-averaged dark data to the file `{output_directory}/stage1_dark_current.fits`.
# To generate a config file template, use `<stage_class>.export_config("filename")`.

# %%
# this dictionary is equivalent to the stage1_parameters-example.asdf file
stage1_args = {'output_dir': "output_stage1", 
               'save_results': True, 
               'steps': {
                   'dark_current': {'output_file': 'stage1_dark_current'},
               }
              }

# %%
# Run Stage 1
if False: # set to True to run or False to use the pre-existing Stage 1 data products
    for data_file in sorted(data_files.values())[:1]:
        print(data_file)
        # the following cases are equivalent; switch by choosing one case to be True
        if True:
            print("Config file")
            det1 = Detector1Pipeline.call(str(data_file), config_file='./parameter_files/stage1_parameters-example.asdf')
        elif False:
            print("Dictionary")
             # split off the step-specific parameters from the top-level parameters
            #step_args = stage1_args.pop('steps')
            det1 = Detector1Pipeline.call(str(data_file), **stage1_args)        
        else:
            print("Object attributes")
            # you can also create a Pipeline class instance and set its properties directly:
            det1 = Detector1Pipeline()
            det1.save_results = True
            det1.output_dir = './output_stage1/'
            det1.dark_current.output_file = 'stage1_dark_current'
            det1.run(str(data_file))
        print(det1)

# %%
# gather a list of the Stage 1 data products
stage1_products = sorted(Path("output_stage1").glob("*rateints.fits"))
list(stage1_products)
# Out:
# [PosixPath('output_stage1/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_rateints.fits'),
#  PosixPath('output_stage1/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll2_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-1_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-2_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-3_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-4_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-5_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-6_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-7_rateints.fits'),
#  PosixPath('output_stage1/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-8_rateints.fits')]

# %% [markdown]
# # Stage 2: Image calibration

# %% [markdown]
# Stage name: `Image2Pipeline`
# > https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_image2.html
#
# Stage 2 imaging processing applies additional instrumental corrections and calibrations that result in a fully calibrated individual exposure.
#
# It uses the following custom arguments, in addtion to the universasl arguments:
# - `save_bsub bool [False]`
# 	- if True, save the results of the background subtraction step to an intermediate file, with product type _bsub or _bsubints depending on if you want to preserve the individual integrations in a 3D datacube

# %% [markdown]
# The steps are:
# - `bkg_subtract`
# 	- subtracts background signal using image-from-image subtraction. Input is a target exposure and one or more background exposures.
# 	- Other methods of background subtraction are available (see here).
# 	- step-specific arguments:
# 		- sigma float [3] number of standard deviations to use for sigma-clipped background computation
# 		- maxiters int [None] number of clipping iterations to perform, None causes algorithm to iterate until convergence
# 		- save_combined_background bool [False] if True, saves the background image
# 	- reference files: only used when processing wide-field slitless spectroscopy exposures (so, not used for coronagraphy)
# - `assign_wcs`
# 	- Associates a WCS object with each science exposure, transforming positionsin the detector frame to positions in a world coordinate frame (ICRS and wavelength).
# 	- WCS is saved in the ASDF extension of the fits file, and can be accessed as an attribute of the meta object when the fits file is opened as a data model
# 	- No step-specific arguments
# 		-     sip_approx: true
# 		-     sip_max_inv_pix_error: 0.25
# 		-     sip_max_pix_error: 0.25
# 		-     sip_npoints: 32
# 		-     slit_y_high: 0.55
# 		-     slit_y_low: -0.55
# 	- reference files: the reference file types used by MIRI are:
# 		- DISTORTION
# 		- FILTEROFFSET
# 		- SPECWCS
# 		- REGIONS
# 		- WAVELENGTHRANGE
# 		- I think only DISTORTION and FILTEROFFSET are used by the coronagraphs
# - `flat_field`
# 	- At its basic level this step flat-fields an input science dataset by dividing by a flat-field reference image. In particular, the SCI array from the flat-field reference file is divided into the SCI array of the science dataset, the flat-field DQ array is combined with the science DQ array using a bitwise OR operation, and variance and error arrays in the science dataset are updated to include the flat-field uncertainty.
# 	- No step-specific arguments  for MIRI (there is one for NIRSpec)
# 	- Reference files types:
# 		- FLAT - contains pixel-by-pixel detector response values
# - `photom`
# 	- applies flux (photometric) calibrations to a data product to convert the data from units of countrate to surface brightness (or, in some cases described below, to units of flux density). The calibration information is read from a photometric reference file. The exact nature of the calibration information loaded from the reference file and applied to the science data depends on the instrument mode
# 	- no step-specific arguments
# 	- reference file types:
# 		- PHOTOM - conversion factors for putting pixel values into physical units
# 		- AREA - pixel area information for a given instrument mode.
# - `resample`
# 	- resample each input 2D image based on the WCS and distortion information, and will combine multiple resampled images into a single undistorted product
# 	- Data products (ending in _i2d ) are only intended for quicklook and are not passed on to Stage 3
# 	- step-specific arguments
# 		- pixfrac float [1.0] fraction by which input pixels are “shrunk” before being drizzled
# 		- kernel str ['square'] The form of the kernel function used to distribute flux onto the output image
# 		- blendheaders bool [True] Blend metadata from all input images into the resampled output image.
# 		- pixel_scale_ratio float [1.0] Ratio of input to output pixel scale
# 		- fillval str ['INDEF'] The value to assign to output pixels that have zero weight or do not receive any flux from any input pixels during drizzling.
# 		- weight_type str ['ivm'] The weighting type for each input image
# 		- single bool [False] resample each input image into a separate output
# 	- reference file types: DRIZPARS

# %%
# this dictionary is equivalent to the stage2_parameters-example.asdf file
stage2_args = {'output_dir': "./output_stage2/", 
               'save_results': True, 
               'save_bsub': True,
               'steps': {
                   'bkg_subtract': {'save_combined_background': True},
               }
              }

# %%
# now, run Stage 2 on each of the Stage 1 data products
if False:
    for filename in stage1_products:
        if False:
            print("Config file")
            img2 = Image2Pipeline.call(str(filename), config_file='./parameter_files/stage2_parameters-example.asdf')
        else:
            print("Dictionary")
            img2 = Image2Pipeline.call(str(filename), **stage2_args)
        print(img2)

# %%
stage2_products = sorted(Path("output_stage2").glob("*calints.fits"))
stage2_products
# Out:
# [PosixPath('output_stage2/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_calints.fits'),
#  PosixPath('output_stage2/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll2_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-1_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-2_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-3_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-4_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-5_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-6_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-7_calints.fits'),
#  PosixPath('output_stage2/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-8_calints.fits')]

# %% [markdown]
# # Stage 3: PSF subtraction

# %% [markdown]
# Stage name: `Coron3Pipeline`
#
# > https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_coron3.html#calwebb-coron3
#
#
# Stage 3 processing is used to produce PSF-subtracted, resampled, combined images of the source object.
#
# Stage 3 has no top-level custom arguments, aside from the universal arguments.
#
# Stage 3 steps and their custom arguments:
#
# - `outlier_detection`
# 	- More sensitive to cosmics, bad pixels, and other outliers than at the jump step
# 	- step-specific arguments
# 		- `weight_type (string, default=’exptime’)` The type of data weighting to use during resampling; options are ‘exptime’, ‘error’, and ‘None’.
# 		- `pixfrac (float, default=1.0)` The pixel fraction used during resampling; valid values go from 0.0 to 1.0.
# 		- `kernel (string, default=’square’)` The form of the kernel function used to distribute flux onto a resampled image. Options are ‘square’, ‘turbo’, ‘point’, ‘lanczos’, and ‘tophat’.
# 		- `fillval (string, default=’INDEF’)` The value to assign to resampled image pixels that have zero weight or do not receive any flux from any input pixels during drizzling. Any floating-point value, given as a string, is valid. A value of ‘INDEF’ will use the last zero weight flux.
# 		- `nlow (integer, default=0)` The number of low values in each pixel stack to ignore when computing the median value.
# 		- `nhigh (integer, default=0)` The number of high values in each pixel stack to ignore when computing the median value.
# 		- `maskpt (float, default=0.7)` The percent of maximum weight to use as lower-limit for valid data; valid values go from 0.0 to 1.0.
# 		- `grow (integer, default=1)` The radius, in pixels, from a bad pixel for neighbor rejection.
# 		- `snr (string, default=’4.0 3.0’)` The signal-to-noise values to use for bad pixel identification. Valid values are a pair of floating-point values in a single string.
# 		- `scale (string, default=’0.5 0.4’)` The scaling factor applied to derivative used to identify bad pixels. Valid values are a pair of floating-point values in a single string.
# 		- `backg (float, default=0.0)` User-specified background value to apply to the median image.
# 		- `save_intermediate_results (boolean, default=False)` Specifies whether or not to save any intermediate products created during step processing.
# 		- `resample_data (boolean, default=True)` Specifies whether or not to resample the input images when performing outlier detection.
# 		- `good_bits (string, default=”~DO_NOT_USE”)` The DQ bit values from the input image DQ arrays that should be considered ‘good’ when building the weight mask. See DQ flag Parameter Specification for details.
# 		- `scale_detection (bool, default=False)` Specifies whether or not to rescale the individual input images to match total signal when doing comparisons.
# 		- `allowed_memory (float, default=None)` Specifies the fractional amount of free memory to allow when creating the resampled image
# 	- reference file types: no reference files used
# - `stack_refs`
# 	- It takes a list of reference PSF products and stacks all of the per-integration images contained in each PSF product into a single 3D data cube.  The image data are simply copied and reformatted, without being modified in any way.
# 	- step-specific arguments: none
# 	- reference file types: no reference files used
# - `align_refs`
# 	- It computes offsets between science target images and reference PSF images, and shifts the PSF images into alignment.
# 	- step-specific arguments
# 		- median_box_length (integer, default=3) The box size to use when replacing bad pixels with the median in a surrounding box.
# 		- bad_bits (string, default=”DO_NOT_USE”)The DQ bit values from the input image DQ arrays that should be considered bad and replaced with the median in a surrounding box.
# 	- reference file types: PSFMASK
# - `klip`
# 	- It applies the Karhunen-Loeve Image Plane (KLIP) algorithm to coronagraphic images, using an accompanying set of reference PSF images, in order to fit and subtract an optimal PSF from a source image
# 	- step-specific arguments
# 		- truncate (integer, 50) This is an integer parameter with a default value of 50 and is used to specify the number of KL transform rows to keep when computing the PSF fit to the target.
# 	- reference file types: none
# - `resample`
# 	- This routine will resample each input 2D image based on the WCS and distortion information, and will combine multiple resampled images into a single undistorted product.
# 	- step-specific arguments: same as for Stage 2
# 	- reference file types: DRIZPARS

# %% [markdown]
# ## Running Stage 3
#
# To perform PSF subtraction, you have to tell Stage 3 which exposures are science targets and which are PSF references. This is done with an "association file", which is documented briefly here https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_coron3.html. In the example below, we will use our pre-defined file names to split the exposures into the appropriate categories and generate an association file in JSON format.

# %%
import json

# %%
output_path = Path("output_stage3")
asn_file = Path("stage3_asn.json")                       # Define ASN file

# make sure you have the right paths
assert(output_path.exists())


# You need an association file. Generate and write it to disk. YAML format is acceptable
# target files
target_files = [f for f in stage2_products if f.name.find('roll') >= 0][:1]
reference_files = [f for f in stage2_products if f.name.find('roll') < 0][:1]

# Most of the preamble stuff doesn't matter, and in practice will be set automatically by the pipeline
# `name` determines the file prefixes
asn = {
    # preamble
    "asn_type": "coron3",
    "asn_rule": "candidate_Asn_Coron",
    "program": "mirisim jwst tutorial",
    "asn_id": "c1001",
    "target": "tutorial",
    "asn_pool": f"tutorial-pool",
    # exposure definitions
    "products": [
        {"name": f"mirisim_jwst_tutorial",
             # 'members' takes a list of dictionaries that associate an exposure type with a file name
             "members": [{'expname': str(ff), 'exptype': 'science'} for ff in target_files] +\
                        [{'expname': str(ff), 'exptype': 'psf'} for ff in reference_files], 

        }
    ]
}

with open(str(asn_file), "w") as outfile:
    json.dump(asn, outfile)
    #yaml.dump(asn, outfile)

assert(asn_file.exists())

# %% [markdown]
# As described earlier, for the moment we need to override the default PSFMASK reference files and provide our own.
# The masks can be found here: https://github.com/STScI-MIRI/Gen_PSFMASK_ref_files/tree/main/psf_masks_new
# - `*0001.fits`: 1065
# - `*0002.fits`: 1550
# - `*0003.fits`: 1140
# - `*0004.fits`: LYOT
#
# (n.b. yes 0002 and 0003 are really out of wavelength order, this is being corrected)
#
# Since we simulated the 1550 4QPM, we choose the appropriate PSFMASK file in the dictionaries below. Once the PSFMASK files in CRDS are corrected, this will be done automatically based on the Stage 2 data product header keywords.

# %%
psfmask_files = {"1065": "./psfmasks/jwst_miri_psfmask_0001.fits",
                 "1140": "./psfmasks/jwst_miri_psfmask_0003.fits",
                 "1550": "./psfmasks/jwst_miri_psfmask_0002.fits",
                 "LYOT": "./psfmasks/jwst_miri_psfmask_0004.fits"}
stage3_params = {"save_results": True,
                 "output_dir": "output_stage3",
                 "steps": {
                     "align_refs": {"override_psfmask": psfmask_files["1550"]}
                 }
                }

# %% [markdown]
# Now, all that's left is to run the pipeline!

# %%
if True:
    # run the pipeline
    if True:
        cor3 = Coron3Pipeline.call(str(asn_file), config_file='./parameter_files/stage3_parameters-example.asdf')                              
    else:
        cor3 = Coron3Pipeline.call(str(asn_file), **stage3_params)

    print(f"\n\nFinished\n\n")
# Out:
# 2021-10-27 09:01:28,576 - stpipe.Coron3Pipeline - INFO - Coron3Pipeline instance created.
# 2021-10-27 09:01:28,578 - stpipe.Coron3Pipeline.stack_refs - INFO - StackRefsStep instance created.
# 2021-10-27 09:01:28,580 - stpipe.Coron3Pipeline.align_refs - INFO - AlignRefsStep instance created.
# 2021-10-27 09:01:28,582 - stpipe.Coron3Pipeline.klip - INFO - KlipStep instance created.
# 2021-10-27 09:01:28,584 - stpipe.Coron3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2021-10-27 09:01:28,586 - stpipe.Coron3Pipeline.resample - INFO - ResampleStep instance created.
# 2021-10-27 09:01:28,678 - stpipe.Coron3Pipeline - INFO - Step Coron3Pipeline running with args ('stage3_asn.json',).
# 2021-10-27 09:01:28,687 - stpipe.Coron3Pipeline - INFO - Step Coron3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'output_stage3', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'steps': {'stack_refs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'align_refs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'median_box_length': 3, 'bad_bits': 'DO_NOT_USE'}, 'klip': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'truncate': 10}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'pixel_scale_ratio': 1.0, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# 2021-10-27 09:01:28,688 - stpipe.Coron3Pipeline - INFO - Starting calwebb_coron3 ...
# 2021-10-27 09:01:28,832 - stpipe.Coron3Pipeline - INFO - Prefetching reference files for dataset: 'piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0_calints.fits' reftypes = ['drizpars']
# 2021-10-27 09:01:29,094 - stpipe.Coron3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/grp/crds/cache/references/jwst/jwst_miri_drizpars_0001.fits'.
# 2021-10-27 09:01:29,138 - stpipe.Coron3Pipeline - INFO - Override for PSFMASK reference file is '/Users/jaguilar/Projects/mirisim/mirisim_jwst_tutorial/psfmasks/jwst_miri_psfmask_0002.fits'.
# 2021-10-27 09:01:29,273 - stpipe.Coron3Pipeline - INFO - Prefetching reference files for dataset: 'Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_calints.fits' reftypes = ['drizpars']
# 2021-10-27 09:01:29,276 - stpipe.Coron3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/grp/crds/cache/references/jwst/jwst_miri_drizpars_0001.fits'.
# 2021-10-27 09:01:29,290 - stpipe.Coron3Pipeline - INFO - Override for PSFMASK reference file is '/Users/jaguilar/Projects/mirisim/mirisim_jwst_tutorial/psfmasks/jwst_miri_psfmask_0002.fits'.
# 2021-10-27 09:01:29,484 - stpipe.Coron3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<CubeModel(16, 224, 288) from piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0_calints.fits>,).
# 2021-10-27 09:01:29,486 - stpipe.Coron3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'c1001_crfints', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2021-10-27 09:01:29,497 - stpipe.Coron3Pipeline.outlier_detection - INFO - Performing outlier detection with 16 inputs
# 2021-10-27 09:01:29,534 - stpipe.Coron3Pipeline.outlier_detection - WARNING - /Users/jaguilar/Projects/miniconda3/envs/mirisim/lib/python3.8/site-packages/jwst/resample/resample_utils.py:156: RuntimeWarning: var_rnoise array not available.  Setting drizzle weight map to 1
#   warnings.warn("var_rnoise array not available.  Setting drizzle weight map to 1",
#
# 2021-10-27 09:01:29,978 - stpipe.Coron3Pipeline.outlier_detection - INFO - Generating median from 16 images
# 2021-10-27 09:01:30,110 - stpipe.Coron3Pipeline.outlier_detection - WARNING - /Users/jaguilar/Projects/miniconda3/envs/mirisim/lib/python3.8/site-packages/jwst/outlier_detection/outlier_detection.py:442: RuntimeWarning: overflow encountered in multiply
#   cr_mask = np.logical_not(np.greater(diff_noise, snr1 * err_data))
#
# 2021-10-27 09:01:31,252 - stpipe.Coron3Pipeline.outlier_detection - INFO - Saved model in output_stage3/piHer-det_image_seq1_MIRIMAGE_F1550Cexp1-0_c1001_crfints.fits
# 2021-10-27 09:01:31,253 - stpipe.Coron3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2021-10-27 09:01:31,328 - stpipe.Coron3Pipeline.stack_refs - INFO - Step stack_refs running with args (<ModelContainer>,).
# 2021-10-27 09:01:31,330 - stpipe.Coron3Pipeline.stack_refs - INFO - Step stack_refs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2021-10-27 09:01:31,338 - stpipe.Coron3Pipeline.stack_refs - INFO -  Adding psf member 1 to output stack
# 2021-10-27 09:01:31,367 - stpipe.Coron3Pipeline.stack_refs - INFO - Step stack_refs done
# 2021-10-27 09:01:31,460 - stpipe.Coron3Pipeline - INFO - Saved model in output_stage3/mirisim_jwst_tutorial_psfstack.fits
# 2021-10-27 09:01:31,655 - stpipe.Coron3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<CubeModel(75, 224, 288) from Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_calints.fits>,).
# 2021-10-27 09:01:31,657 - stpipe.Coron3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'c1001_crfints', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2021-10-27 09:01:31,668 - stpipe.Coron3Pipeline.outlier_detection - INFO - Performing outlier detection with 75 inputs
# 2021-10-27 09:01:31,699 - stpipe.Coron3Pipeline.outlier_detection - WARNING - /Users/jaguilar/Projects/miniconda3/envs/mirisim/lib/python3.8/site-packages/jwst/resample/resample_utils.py:156: RuntimeWarning: var_rnoise array not available.  Setting drizzle weight map to 1
#   warnings.warn("var_rnoise array not available.  Setting drizzle weight map to 1",
#
# 2021-10-27 09:01:33,552 - stpipe.Coron3Pipeline.outlier_detection - INFO - Generating median from 75 images
# 2021-10-27 09:01:33,902 - stpipe.Coron3Pipeline.outlier_detection - WARNING - /Users/jaguilar/Projects/miniconda3/envs/mirisim/lib/python3.8/site-packages/jwst/outlier_detection/outlier_detection.py:442: RuntimeWarning: overflow encountered in multiply
#   cr_mask = np.logical_not(np.greater(diff_noise, snr1 * err_data))
#
# 2021-10-27 09:01:38,882 - stpipe.Coron3Pipeline.outlier_detection - INFO - Saved model in output_stage3/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_c1001_crfints.fits
# 2021-10-27 09:01:38,883 - stpipe.Coron3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2021-10-27 09:01:39,003 - stpipe.Coron3Pipeline.align_refs - INFO - Step align_refs running with args (<CubeModel(75, 224, 288) from Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_c1001_crfints.fits>, <CubeModel(16, 224, 288) from mirisim_jwst_tutorial_psfstack.fits>).
# 2021-10-27 09:01:39,005 - stpipe.Coron3Pipeline.align_refs - INFO - Step align_refs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'median_box_length': 3, 'bad_bits': 'DO_NOT_USE'}
# 2021-10-27 09:01:39,016 - stpipe.Coron3Pipeline.align_refs - INFO - Using PSFMASK reference file /Users/jaguilar/Projects/mirisim/mirisim_jwst_tutorial/psfmasks/jwst_miri_psfmask_0002.fits
# 2021-10-27 09:01:39,060 - stpipe.Coron3Pipeline.align_refs - WARNING - /Users/jaguilar/Projects/miniconda3/envs/mirisim/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
#
# 2021-10-27 09:01:39,061 - stpipe.Coron3Pipeline.align_refs - WARNING - /Users/jaguilar/Projects/miniconda3/envs/mirisim/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#
# 2021-10-27 09:01:39,062 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,063 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,063 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,064 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,065 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,065 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,066 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,067 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,068 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,068 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,069 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,070 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,070 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,071 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,072 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,073 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,074 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,074 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,075 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,076 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,077 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,078 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,078 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,079 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,080 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,081 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,081 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,082 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,083 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,083 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,084 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,085 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,085 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,086 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,087 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,087 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,088 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,089 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,090 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,090 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,091 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,092 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,092 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,093 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,093 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,094 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,094 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,095 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,096 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,097 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,098 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,098 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,099 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,100 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,101 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,101 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,102 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,102 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,103 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,104 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,104 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,105 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,106 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,106 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,107 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,108 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,108 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,109 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,110 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,110 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,111 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,112 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,112 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,113 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,114 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,114 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,115 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,115 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,116 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,117 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,118 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,118 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,119 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,120 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,121 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,121 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,122 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,123 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,123 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,124 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,125 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,125 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,126 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,127 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,128 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,128 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,129 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,130 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,130 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,131 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,131 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,132 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,133 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,133 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,134 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,135 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,135 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,136 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,136 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,137 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,138 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,138 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,139 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,140 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,140 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,141 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,142 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,142 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,143 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,144 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,144 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,145 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,145 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,146 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,147 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,148 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,149 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,149 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,150 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,151 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,151 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,152 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,153 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,153 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,154 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,155 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,156 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,156 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,157 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,158 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,158 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,159 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,160 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,160 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,161 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,162 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,163 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,163 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,164 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,165 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,165 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,166 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,167 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,167 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,168 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,169 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,169 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,170 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,171 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,171 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,172 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,173 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,174 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,174 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,175 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,176 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,176 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,177 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,178 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,179 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,179 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,180 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,181 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,181 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,182 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,183 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,183 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,184 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,185 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,185 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,186 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,187 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,187 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,188 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,189 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,191 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,192 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,193 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,193 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,194 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,195 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,195 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,196 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,197 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,198 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,198 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,199 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,200 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,200 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,201 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,202 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,202 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,203 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,203 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,204 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,205 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,205 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,206 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,207 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,207 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,208 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,209 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,209 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,210 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,211 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,211 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,212 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,213 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,213 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,214 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,215 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,215 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,216 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,217 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,217 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,218 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,218 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,219 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,220 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,220 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,221 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,222 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,222 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,223 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,224 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,225 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,225 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,226 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,227 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,228 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,228 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,229 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,230 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,231 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,232 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,233 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,243 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,244 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,245 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,246 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,246 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,249 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,249 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,250 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,251 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,251 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,252 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,253 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,254 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,254 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,255 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,256 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,257 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,257 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,258 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,259 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,260 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,260 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,261 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,261 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,262 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,263 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,264 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,264 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,265 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,266 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,266 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,267 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,268 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,268 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,269 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,270 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,271 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,271 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,272 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,273 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,274 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,274 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,275 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,276 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,277 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,277 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,278 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,279 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,280 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,281 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,281 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,282 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,283 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,283 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,284 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,285 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,285 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,286 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,287 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,288 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,289 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,290 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,291 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,292 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,293 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,294 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,295 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,296 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,298 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,300 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,301 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:01:39,303 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# ...
# 2021-10-27 09:21:49,984 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,984 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,985 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,986 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,986 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,987 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,987 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,988 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,989 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,989 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,990 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,991 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,991 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,992 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,993 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,993 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,994 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,994 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,995 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,996 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,996 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,997 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,998 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,998 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:49,999 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,000 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,001 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,002 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,002 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,003 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,004 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,005 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,005 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,006 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,007 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,007 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,008 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,009 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,009 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,010 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,011 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,011 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,012 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,013 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,014 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,014 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,015 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,016 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,017 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,017 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,018 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,019 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,020 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,020 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,021 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,022 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,022 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,023 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,024 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,024 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,026 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,027 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,028 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,029 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,030 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,031 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,032 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,033 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,033 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,034 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,035 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,036 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,037 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,038 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,039 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,040 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,042 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,043 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,043 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,045 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,046 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,046 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,048 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,049 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,049 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,050 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,051 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,053 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,054 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,056 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,058 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,059 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,060 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,060 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,061 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,062 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,062 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,063 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,063 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,064 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,065 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,065 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,066 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,067 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,068 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,069 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,070 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,071 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,078 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,079 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,080 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,083 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,086 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,087 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,088 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,090 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,090 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,091 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,091 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,092 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,092 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,093 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,094 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,094 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,095 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,096 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,096 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,097 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,097 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,098 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,099 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,099 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,100 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,100 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.
# 2021-10-27 09:21:50,101 - stpipe.Coron3Pipeline.align_refs - WARNING - Median filter returned NaN setting value to 0.

# %% [markdown]
# The step that takes the longest is the reference image alignment ("`align_refs`"). As an exercise to the user, see if you can find the flag to save the alignment products to the Stage 3 output folder, and then to read them back in for subsequent Stage 3 runs.

# %% [markdown]
# [Top of Page](#title_ID)
# <a id="output"></a>
# --------------
# # Output products
#
# - `_crfints.fits` : cosmics and outliers removed bu `outlier_detection` step
# - `_psfstack.fits` : all the reference exposures, concatenated into a single cube by the `stack_refs` step
# - `_psfalign.fits` : for each science target exposure, all the slices of the `psfstack` product are aligned to each science target *integration* by the `align_refs` step and saved as a 4D cube
# - `_psfsub.fits` : for each science target exposure, KLthe `klip` step generates a model PSF for each integration and subtracts it off, resulting in a 3D cube
# - `_i2d.fits` : The `resample` step is applied to the CR-flagged products to create a single resampled and combined product for the science targethe resample step is applied to the CR-flagged products to create a single resampled and combined product for the science targethe resample step is applied to the CR-flagged products to create a single resampled and combined product for the science target

# %% [markdown]
# <a id="stack_refs"></a>
# ###  `stack_refs`:  Stack PSF References (*'_psfstack' product*)
#
# The role of the `stack_refs` step is to stack all of the PSF reference exposures (specified in the input ASN file) into a single `CubeModel` for use by subsequent coronagraphic steps. The size of the stack should be equal to the sum of the number of integrations in each input PSF exposure.  The image data are simply copied and reformatted and should not be modified in any way.
#
# *Output*: **3D PSF Image Stack** <br>
# *File suffix*: **'_psfstack'**
#
# > Step description: https://jwst-pipeline.readthedocs.io/en/latest/jwst/stack_refs/index.html#stack-refs-step

# %%
from IPython.display import display,clear_output

# %%
stacked_cube_hdu = fits.open('output_stage3/mirisim_jwst_tutorial_psfstack.fits')
ref_images = stacked_cube_hdu[1].data
print(stacked_cube_hdu.info())

# %%
print("'_psfstack' data product dimensions: "+str(ref_images.shape))

# %% [markdown]
# ------------
# <a id="klip"></a>
# ### `klip`:  Reference PSF Subtraction
#
# The role of the `klip` step is to apply the Karhunen-Loeve Image Plane (KLIP) algorithm on the science target images, using an accompanying set of aligned reference PSF images (result of the `align_refs` step) in order to fit and subtract an optimal PSF from the science target image. The PSF fitting and subtraction is applied to each integration image independently. The output is a 3D stack of PSF-subtracted images of the science target, having the same dimensions as the input science target product.
#
# *Output*: **3D PSF-subtracted image** <br>
# *File suffix*: **_psfsub**
#
# > Step description: https://jwst-pipeline.readthedocs.io/en/latest/jwst/klip/index.html#klip-step

# %%
sub_hdu = fits.open('output_stage3/Vega-det_image_seq1_MIRIMAGE_F1550Cexp1-roll1_c1001_psfsub.fits')
sub_hdu.info()

# %%
subtracted_image = sub_hdu[1].data
print("Science target image dimensions: " + str(subtracted_image.shape))
print("PSF subtracted image dimensions: " + str(subtracted_image.shape))

# %% [markdown]
# Note that the PSF subtracted image has the same dimensions as the input target image.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8))
ax = axes[0]
ax.set_title("Slice of PSF subtracted image")
imax = ax.imshow(subtracted_image[50],
                 vmin = 0, vmax = 10,
                 interpolation ="none", origin='lower')
fig.colorbar(imax, ax=ax, orientation='horizontal')

ax = axes[1]
ax.set_title("Median PSF subtracted image")
imax = ax.imshow(np.median(subtracted_image, axis=0),
                 #vmin = 0, vmax = 10,
                 norm=mpl.colors.SymLogNorm(1),
                 interpolation ="none", origin='lower')
fig.colorbar(imax, ax=ax, orientation='horizontal')
